# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import seaborn as sns

# %%
# Read songs dataset with labels and tags
data_frame = pd.read_csv("final_dataset.csv",)
data_frame
# Out:
#       song_name  song_popularity  acousticness  danceability  energy  \
# 0       2:00 AM               57       0.11900         0.663   0.762
# 1         03:15               76       0.38500         0.651   0.654
# 2         06:30               74       0.14900         0.757   0.579
# 3         06:30               74       0.14900         0.757   0.579
# 4       3:00 PM               47       0.81000         0.548   0.438
# ...         ...              ...           ...           ...     ...
# 18830   Zum Zum               83       0.06220         0.839   0.832
# 18831     Zumba               60       0.00205         0.729   0.894
# 18832      TRUE               74       0.50600         0.744   0.545
# 18833      TRUE               68       0.50600         0.744   0.545
# 18834      TRUE               44       0.27000         0.591   0.679
#
#        instrumentalness  key  liveness  loudness  speechiness     tempo  \
# ...

# %%
# Mood identification and recommendation
cluster_info = []
mood_info = []
for i in range(3):
    value1 = input("Please enter song name:\n") 
    found1 = data_frame[data_frame['song_name'].str.contains(value1, na=False, case=False)]
    cluster_info.append(found1['label'].tolist()[0])
    mood_info.append(found1['tag'].tolist()[0])

# over here we identify the mood based on user inputs   
cluster = max(cluster_info,key=cluster_info.count)
mood = max(mood_info,key=mood_info.count)


data_frame_temp = data_frame[ data_frame['label']==cluster ]
data_frame_temp = data_frame_temp[ data_frame['tag']==mood ]


data_frame_temp.drop_duplicates(subset ="song_name", keep = False, inplace = True) 

# over here we recommend the list of songs.
data_frame_temp = data_frame_temp.sort_values(by=['song_popularity'],ascending = False)[0:50].sample(10)

data_frame_temp.sort_values(by=['song_popularity'],ascending = False)
# Out:
# Please enter song name:
# 24K magic
# Please enter song name:
# Zebra
# Please enter song name:
# Zumba
# C:\Users\jshar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                      song_name  song_popularity  acousticness  \
# 3678                           Cuando Nadie Ve               85        0.1180
# 4175                                    Djadja               84        0.1170
# 12674                                Por Perro               84        0.4190
# 4787                          El Clavo - Remix               84        0.0576
# 13512  Rockabye (feat. Sean Paul & Anne-Marie)               83        0.4060
# 10412       Medley da Gaiola - Dennis DJ Remix               83        0.7020
# 405                          ¿Cual es tu plan?               82        0.4150
# 2823                        Can't Feel My Face               82        0.1120
# ...
